# %% [markdown]
# # Machine Learning: Apprentissage Non-Supervisé
#
# - Chrysalde CARON
# - Valentin ANOT
#
# ## Librairies externes
#
# - numpy : Génération de nombres aléatoires et lecture/écriture de fichiers `.npy`
# - matplotlib : Génération de graphes
# - scikit-learn : Clustering et Heuristiques
#
# ## Exercice 1

# %%
import Exercice1.Exercice1 as ex1

ex1.Exercice1()
# Out:
# here is a representation of the hair color and the percentage of them in the population
# we sample it to 10000
# the expected value is :10.5

# %% [markdown]
# Le programme génére 6 colomne de dataset, la première ne contient uniquement  que des integers, la deuxième ne contient ,elle, que des float. La troisième possède une moyenne de 2.5. La quatrième colomne reprend la première fait en sorte qu'elle soit corrélée positivement. La cinquième est l'inverse de la quatrième mais en prennant la deuxième colonne comme référence. La sixieme et dernière columne possède juste une correlation proche de zero.

# %% [markdown]
# ## Exercice 2

# %%
import Exercice2.Exercice2 as ex2

ex2.Exercice2()

# %% [markdown]
# ## Exercice 3

# %%
import Exercice3.Exercice3 as ex3
ex3.Exercice3()

# %% [markdown]
# ## Exercice 4
#
# L'objectif de l'exercice était de créer une police stochastique permettant aux agents d'obtenir un niveau moyen d'au moins 20.
#
# Le fichier `simulation.py` as été modifié de façon à ce qu'un appel externe puisse définir une police sans avoir besoin de modifier le fichier, lancer le fichier en tant que script lancera la police par défaut, tandis que le bloc de code ci-dessous lancera la simulation avec la police définie dans `chrysalde_policy.py`.

# %%
from Exercice4 import simulation, chrysalde_policy as policy

simulation.current_policy = policy.chrysalde_policy

simulation.main()
# Out:
# final reward: 27.810
